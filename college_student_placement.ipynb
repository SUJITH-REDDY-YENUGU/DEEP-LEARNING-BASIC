# %% [markdown]
# 📄 Dataset Description
# This dataset simulates the academic and professional profiles of 10,000 college students, focusing on factors that influence placement outcomes. It includes features like IQ, academic performance, CGPA, internships, communication skills, and more.
#
# The dataset is ideal for:
#
# Predictive modeling of placement outcomes
# Educational exercises in classification
# Feature importance analysis
# End-to-end machine learning projects
# 📊 Columns Description
# Column Name	Description
# College_ID	Unique ID of the college (e.g., CLG0001 to CLG0100)
# IQ	Student’s IQ score (normally distributed around 100)
# Prev_Sem_Result	GPA from the previous semester (range: 5.0 to 10.0)
# CGPA	Cumulative Grade Point Average (range: ~5.0 to 10.0)
# Academic_Performance	Annual academic rating (scale: 1 to 10)
# Internship_Experience	Whether the student has completed any internship (Yes/No)
# Extra_Curricular_Score	Involvement in extracurriculars (score from 0 to 10)
# Communication_Skills	Soft skill rating (scale: 1 to 10)
# Projects_Completed	Number of academic/technical projects completed (0 to 5)
# Placement	Final placement result (Yes = Placed, No = Not Placed)
# 🎯 Target Variable
# Placement: This is the binary classification target (Yes/No) that you can try to predict based on the other features.
# 🧠 Use Cases
# 📈 Classification Modeling (Logistic Regression, Decision Trees, Random Forest, etc.)
# 🔍 Exploratory Data Analysis (EDA)
# 🎯 Feature Engineering and Selection
# 🧪 Model Evaluation Practice
# 👩‍🏫 Academic Projects & Capstone Use
# 📦 Dataset Size
# Rows: 10,000
# Columns: 10
# File Format: .csv
# 📚 Context
# This dataset was generated to resemble real-world data in academic institutions for research and machine learning use. While it is synthetic, the variables and relationships are crafted to mimic authentic trends observed in student placements.
#
# 📜 License
# MIT
#
# 🔗 Source
# Created using Python (NumPy, Pandas) with data logic designed for educational and ML experimentation purposes.
#
# You can get the dataset from the link : https://www.kaggle.com/datasets/sahilislam007/college-student-placement-factors-dataset

# %%
#doing data cleaning and data prepatation for the deep learning model 
import pandas as pd
dataframe=pd.read_csv("college_student_placement_dataset.csv")
print(f"The shape of the dataset : {dataframe.shape}")
print(f"\033[1;36m{"="*130}\033[0m")
print(f"Description about the dataset ")
print(dataframe.describe())
print(f"\033[1;36m{"="*130}\033[0m")
print(f"Info about the dataset ....")
print(dataframe.info())
print(f"\033[1;36m{"="*130}\033[0m")
# Out:
# The shape of the dataset : (10000, 10)
# ==================================================================================================================================
# Description about the dataset
#                  IQ  Prev_Sem_Result          CGPA  Academic_Performance  \
# count  10000.000000     10000.000000  10000.000000          10000.000000
# mean      99.471800         7.535673      7.532379              5.546400
# std       15.053101         1.447519      1.470141              2.873477
# min       41.000000         5.000000      4.540000              1.000000
# 25%       89.000000         6.290000      6.290000              3.000000
# 50%       99.000000         7.560000      7.550000              6.000000
# 75%      110.000000         8.790000      8.770000              8.000000
# max      158.000000        10.000000     10.460000             10.000000
#
#        Extra_Curricular_Score  Communication_Skills  Projects_Completed
# count            10000.000000          10000.000000        10000.000000
# mean                 4.970900              5.561800            2.513400
# std                  3.160103              2.900866            1.715959
# min                  0.000000              1.000000            0.000000
# 25%                  2.000000              3.000000            1.000000
# 50%                  5.000000              6.000000            3.000000
# 75%                  8.000000              8.000000            4.000000
# max                 10.000000             10.000000            5.000000
# ==================================================================================================================================
# Info about the dataset ....
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   College_ID              10000 non-null  object
#  1   IQ                      10000 non-null  int64
#  2   Prev_Sem_Result         10000 non-null  float64
#  3   CGPA                    10000 non-null  float64
#  4   Academic_Performance    10000 non-null  int64
#  5   Internship_Experience   10000 non-null  object
#  6   Extra_Curricular_Score  10000 non-null  int64
#  7   Communication_Skills    10000 non-null  int64
#  8   Projects_Completed      10000 non-null  int64
#  9   Placement               10000 non-null  object
# dtypes: float64(2), int64(5), object(3)
# memory usage: 781.4+ KB
# None
# ==================================================================================================================================

# %%
print("checking for missing values .....")
print(dataframe.isna().sum())
print("Checking for the duplicated values ....")
print(dataframe.duplicated().sum())
# Out:
# checking for missing values .....
# College_ID                0
# IQ                        0
# Prev_Sem_Result           0
# CGPA                      0
# Academic_Performance      0
# Internship_Experience     0
# Extra_Curricular_Score    0
# Communication_Skills      0
# Projects_Completed        0
# Placement                 0
# dtype: int64
# Checking for the duplicated values ....
# 0

# %%
print(f"There are no missing values and duplicated values ")
print("Reading column names and removing unnecessay values ")
print(dataframe.columns)
# Out:
# There are no missing values and duplicated values
# Reading column names and removing unnecessay values
# Index(['College_ID', 'IQ', 'Prev_Sem_Result', 'CGPA', 'Academic_Performance',
#        'Internship_Experience', 'Extra_Curricular_Score',
#        'Communication_Skills', 'Projects_Completed', 'Placement'],
#       dtype='object')

# %%
# we do not need college id so removing it initially
dataframe.drop(columns=["College_ID"],inplace=True)
print(dataframe.columns)
df_columns=dataframe.columns
# Out:
# Index(['IQ', 'Prev_Sem_Result', 'CGPA', 'Academic_Performance',
#        'Internship_Experience', 'Extra_Curricular_Score',
#        'Communication_Skills', 'Projects_Completed', 'Placement'],
#       dtype='object')

# %%
#iterating through every column and knowing its values 
for i in df_columns:
        print(i)
        print(dataframe[i].value_counts)
        print("="*130)
# Out:
# IQ
# <bound method IndexOpsMixin.value_counts of 0       107
# 1        97
# 2       109
# 3       122
# 4        96
#        ...
# 9995    119
# 9996     70
# 9997     89
# 9998    107
# 9999    109
# Name: IQ, Length: 10000, dtype: int64>
# ==================================================================================================================================
# Prev_Sem_Result
# <bound method IndexOpsMixin.value_counts of 0       6.61
# 1       5.52
# 2       5.36
# 3       5.47
# 4       7.91
#         ...
# 9995    8.41
# 9996    9.25
# 9997    6.08
# 9998    8.77
# 9999    9.41
# Name: Prev_Sem_Result, Length: 10000, dtype: float64>
# ==================================================================================================================================
# CGPA
# <bound method IndexOpsMixin.value_counts of 0       6.28
# 1       5.37
# 2       5.83
# 3       5.75
# 4       7.69
#         ...
# 9995    8.29
# 9996    9.34
# 9997    6.25
# 9998    8.92
# 9999    9.77
# Name: CGPA, Length: 10000, dtype: float64>
# ==================================================================================================================================
# Academic_Performance
# <bound method IndexOpsMixin.value_counts of 0       8
# 1       8
# 2       9
# 3       6
# 4       7
#        ..
# 9995    4
# 9996    7
# 9997    3
# 9998    3
# 9999    8
# Name: Academic_Performance, Length: 10000, dtype: int64>
# ==================================================================================================================================
# Internship_Experience
# <bound method IndexOpsMixin.value_counts of 0        No
# 1        No
# 2        No
# 3       Yes
# 4        No
#        ...
# 9995     No
# 9996     No
# 9997    Yes
# 9998     No
# 9999     No
# Name: Internship_Experience, Length: 10000, dtype: object>
# ==================================================================================================================================
# Extra_Curricular_Score
# <bound method IndexOpsMixin.value_counts of 0       8
# 1       7
# 2       3
# 3       1
# 4       8
#        ..
# 9995    1
# 9996    0
# 9997    3
# 9998    7
# 9999    3
# Name: Extra_Curricular_Score, Length: 10000, dtype: int64>
# ==================================================================================================================================
# Communication_Skills
# <bound method IndexOpsMixin.value_counts of 0        8
# 1        8
# 2        1
# 3        6
# 4       10
#         ..
# 9995     8
# 9996     7
# 9997     9
# 9998     5
# 9999     5
# Name: Communication_Skills, Length: 10000, dtype: int64>
# ==================================================================================================================================
# Projects_Completed
# <bound method IndexOpsMixin.value_counts of 0       4
# 1       0
# 2       1
# 3       1
# 4       2
#        ..
# 9995    0
# 9996    2
# 9997    5
# 9998    1
# 9999    5
# Name: Projects_Completed, Length: 10000, dtype: int64>
# ==================================================================================================================================
# Placement
# <bound method IndexOpsMixin.value_counts of 0        No
# 1        No
# 2        No
# 3        No
# 4        No
#        ...
# 9995    Yes
# 9996     No
# 9997     No
# 9998     No
# 9999     No
# Name: Placement, Length: 10000, dtype: object>
# ==================================================================================================================================

# %%
#getting object datatypes to convert into integer or float dtype
list_objects=[]
list_numbers=[]
for i in df_columns:
        if(str(dataframe[i].dtype)=="object"):
                list_objects.append(i)
        else:
                list_numbers.append(i)
print(list_objects)
print(list_numbers)
# Out:
# ['Internship_Experience', 'Placement']
# ['IQ', 'Prev_Sem_Result', 'CGPA', 'Academic_Performance', 'Extra_Curricular_Score', 'Communication_Skills', 'Projects_Completed']

# %%
#checking out the object type classes
for i in list_objects:

        print(dataframe[i].value_counts())
        print("="*80)
# Out:
# Internship_Experience
# No     6036
# Yes    3964
# Name: count, dtype: int64
# ================================================================================
# Placement
# No     8341
# Yes    1659
# Name: count, dtype: int64
# ================================================================================

# %%
#applying directly to columns 
from sklearn.preprocessing import LabelEncoder
encoder=LabelEncoder()
list_encoders={}
for i in list_objects:
        dataframe[i]=encoder.fit_transform(dataframe[i])
        list_encoders[i]=encoder.classes_
for i in list_objects:
        print(dataframe[i].value_counts())
# Out:
# Internship_Experience
# 0    6036
# 1    3964
# Name: count, dtype: int64
# Placement
# 0    8341
# 1    1659
# Name: count, dtype: int64

# %%
for i in list_objects:
        print(dataframe[i].dtype)
        print(dataframe[i].value_counts())
print(list_encoders)
dict_encoded={
        "Yes":1,
        "No":0
}
# Out:
# int32
# Internship_Experience
# 0    6036
# 1    3964
# Name: count, dtype: int64
# int32
# Placement
# 0    8341
# 1    1659
# Name: count, dtype: int64
# {'Internship_Experience': array(['No', 'Yes'], dtype=object), 'Placement': array(['No', 'Yes'], dtype=object)}

# %%
for i in df_columns:
        print(i)
        print(dataframe[i].dtype)
# Out:
# IQ
# int64
# Prev_Sem_Result
# float64
# CGPA
# float64
# Academic_Performance
# int64
# Internship_Experience
# int32
# Extra_Curricular_Score
# int64
# Communication_Skills
# int64
# Projects_Completed
# int64
# Placement
# int32

# %%
X=dataframe.drop(columns=["Placement"],inplace=False)
y=dataframe["Placement"]
print(X.shape)
print(y.shape)
print(X[:2])
print(X[:2])
# Out:
# (10000, 8)
# (10000,)
#     IQ  Prev_Sem_Result  CGPA  Academic_Performance  Internship_Experience  \
# 0  107             6.61  6.28                     8                      0
# 1   97             5.52  5.37                     8                      0
#
#    Extra_Curricular_Score  Communication_Skills  Projects_Completed
# 0                       8                     8                   4
# 1                       7                     8                   0
#     IQ  Prev_Sem_Result  CGPA  Academic_Performance  Internship_Experience  \
# 0  107             6.61  6.28                     8                      0
# 1   97             5.52  5.37                     8                      0
#
#    Extra_Curricular_Score  Communication_Skills  Projects_Completed
# 0                       8                     8                   4
# 1                       7                     8                   0

# %%
from sklearn.model_selection import train_test_split
x_train_df,x_test_df,y_train_df,y_test_df=train_test_split(X,y,train_size=0.8,random_state=42)
print(x_train_df.shape)
print(x_test_df.shape)
print(y_train_df.shape)
print(y_test_df.shape)
# Out:
# (8000, 8)
# (2000, 8)
# (8000,)
# (2000,)

# %%
x_train=x_train_df.to_numpy()
x_test=x_test_df.to_numpy()
y_train=y_train_df.to_numpy()
y_test=y_test_df.to_numpy()
print(type(x_train))
print(type(x_test))
print(type(y_train))
print(type(y_test))
# Out:
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>

# %%
#getting to the tensor data-type
import torch as t

x_train=t.from_numpy(x_train)
x_test=t.from_numpy(x_test)
y_train=t.from_numpy(y_train)
y_test=t.from_numpy(y_test)


print(type(x_train))
print(type(x_test))
print(type(y_train))
print(type(y_test))
# Out:
# <class 'torch.Tensor'>
# <class 'torch.Tensor'>
# <class 'torch.Tensor'>
# <class 'torch.Tensor'>

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# torch.Size([8000, 8])
# torch.Size([2000, 8])
# torch.Size([8000])
# torch.Size([2000])

# %%
from torch.utils.data import Dataset
from torch.utils.data import DataLoader
import torch.nn as nn
class Dataset_creator(Dataset):
        def __init__(self,X_val,y_val):
                
                self.x=X_val
                self.y=y_val
        def __len__(self):
                return len(self.y)
        def __getitem__(self, index):
                return self.x[index],self.y[index]

# %%
train_dataset=Dataset_creator(X_val=x_train,y_val=y_train)
test_dataset=Dataset_creator(X_val=x_test,y_val=y_test)
print(len(train_dataset))
print(len(test_dataset))
# Out:
# 8000
# 2000

# %%
train_dataloader=DataLoader(dataset=train_dataset,shuffle=True,drop_last=True,batch_size=32,num_workers=0)
test_dataloader=DataLoader(dataset=test_dataset,shuffle=True,drop_last=True,batch_size=32,num_workers=0)

# %%
print(len(train_dataloader))
print(len(test_dataloader))
# Out:
# 250
# 62

# %%
for idx,(X,y) in enumerate(train_dataloader):
        print(f"Batch:{idx}")
        print(X.shape)
        print(y.shape)
        print(f"\033[1;36m{"="*150}\033[0m")
# Out:
# Batch:0
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:1
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:2
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:3
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:4
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:5
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:6
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:7
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:8
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:9
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:10
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:11
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:12
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:13
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:14
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:15
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:16
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:17
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:18
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:19
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:20
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:21
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:22
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:23
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:24
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:25
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:26
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:27
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:28
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:29
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:30
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:31
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:32
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:33
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:34
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:35
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:36
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:37
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:38
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:39
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:40
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:41
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:42
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:43
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:44
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:45
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:46
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:47
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:48
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:49
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:50
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:51
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:52
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:53
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:54
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:55
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:56
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:57
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:58
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:59
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:60
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:61
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:62
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:63
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:64
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:65
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:66
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:67
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:68
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:69
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:70
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:71
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:72
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:73
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:74
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:75
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:76
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:77
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:78
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:79
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:80
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:81
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:82
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:83
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:84
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:85
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:86
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:87
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:88
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:89
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:90
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:91
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:92
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:93
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:94
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:95
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:96
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:97
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:98
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:99
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:100
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:101
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:102
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:103
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:104
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:105
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:106
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:107
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:108
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:109
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:110
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:111
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:112
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:113
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:114
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:115
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:116
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:117
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:118
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:119
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:120
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:121
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:122
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:123
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:124
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:125
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:126
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:127
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:128
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:129
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:130
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:131
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:132
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:133
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:134
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:135
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:136
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:137
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:138
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:139
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:140
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:141
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:142
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:143
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:144
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:145
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:146
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:147
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:148
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:149
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:150
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:151
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:152
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:153
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:154
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:155
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:156
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:157
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:158
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:159
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:160
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:161
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:162
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:163
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:164
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:165
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:166
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:167
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:168
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:169
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:170
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:171
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:172
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:173
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:174
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:175
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:176
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:177
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:178
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:179
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:180
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:181
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:182
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:183
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:184
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:185
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:186
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:187
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:188
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:189
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:190
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:191
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:192
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:193
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:194
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:195
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:196
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:197
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:198
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:199
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:200
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:201
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:202
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:203
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:204
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:205
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:206
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:207
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:208
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:209
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:210
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:211
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:212
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:213
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:214
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:215
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:216
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:217
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:218
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:219
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:220
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:221
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:222
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:223
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:224
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:225
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:226
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:227
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:228
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:229
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:230
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:231
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:232
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:233
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:234
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:235
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:236
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:237
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:238
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:239
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:240
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:241
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:242
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:243
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:244
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:245
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:246
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:247
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:248
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================
# Batch:249
# torch.Size([32, 8])
# torch.Size([32])
# ======================================================================================================================================================

# %%
class Model(nn.Module):
        def __init__(self,input_size,hidden_size,output_size):
                super().__init__()
                self.Layer1=nn.Sequential(
                        nn.Linear(input_size,hidden_size),
                        nn.ReLU(),
                        nn.Linear(hidden_size,hidden_size),
                        nn.ReLU(),
                        nn.Dropout(p=0.2),
                        nn.BatchNorm1d(hidden_size),
                        nn.Linear(hidden_size,hidden_size),
                        nn.Dropout(p=0.1),
                        nn.ReLU(),
                        nn.Linear(hidden_size,hidden_size),
                        nn.ReLU(),
                        nn.Linear(hidden_size,hidden_size),
                        nn.ReLU(),
                        nn.Linear(hidden_size,output_size)

                )
        def forward(self,x):
                return self.Layer1(x)

# %%
Model_classifier=Model(8,hidden_size=200,output_size=1)

# %%
from torchinfo import summary
summary(
        model=Model_classifier,
        input_size=(32,8),
        col_names=["input_size","output_size","num_params","trainable"])
# Out:
# ============================================================================================================================================
# Layer (type:depth-idx)                   Input Shape               Output Shape              Param #                   Trainable
# ============================================================================================================================================
# Model                                    [32, 8]                   [32, 1]                   --                        True
# ├─Sequential: 1-1                        [32, 8]                   [32, 1]                   --                        True
# │    └─Linear: 2-1                       [32, 8]                   [32, 200]                 1,800                     True
# │    └─ReLU: 2-2                         [32, 200]                 [32, 200]                 --                        --
# │    └─Linear: 2-3                       [32, 200]                 [32, 200]                 40,200                    True
# │    └─ReLU: 2-4                         [32, 200]                 [32, 200]                 --                        --
# │    └─Dropout: 2-5                      [32, 200]                 [32, 200]                 --                        --
# │    └─BatchNorm1d: 2-6                  [32, 200]                 [32, 200]                 400                       True
# │    └─Linear: 2-7                       [32, 200]                 [32, 200]                 40,200                    True
# │    └─Dropout: 2-8                      [32, 200]                 [32, 200]                 --                        --
# │    └─ReLU: 2-9                         [32, 200]                 [32, 200]                 --                        --
# │    └─Linear: 2-10                      [32, 200]                 [32, 200]                 40,200                    True
# │    └─ReLU: 2-11                        [32, 200]                 [32, 200]                 --                        --
# │    └─Linear: 2-12                      [32, 200]                 [32, 200]                 40,200                    True
# │    └─ReLU: 2-13                        [32, 200]                 [32, 200]                 --                        --
# │    └─Linear: 2-14                      [32, 200]                 [32, 1]                   201                       True
# ============================================================================================================================================
# Total params: 163,201
# Trainable params: 163,201
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 5.22
# ============================================================================================================================================
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.31
# Params size (MB): 0.65
# Estimated Total Size (MB): 0.96
# ============================================================================================================================================

# %%
optimizer=t.optim.Adam(params=Model_classifier.parameters(),lr=1e-2)
lossfn=t.nn.BCEWithLogitsLoss()

# %%
#training
import pyttsx3
Model_classifier.to(t.float32)
t.manual_seed(42)
train_loss_list=[]
test_loss_list=[]
train_acc_list=[]
test_acc_list=[]
epochs=40
for epoch in range(epochs):
        train_acc=0
        train_loss=0
        test_acc=0
        test_loss=0
        Model_classifier.train()
        for (X,y) in train_dataloader:
                X=X.to(t.float32)
                y_preds=Model_classifier(X)
                y_preds=y_preds.squeeze(dim=1)
                y=y.to(t.float32)
                loss=lossfn(y_preds,y)
                train_loss+=loss.item()*32 # batchsize=32
                train_acc+=(t.round(y_preds)==y).sum().item()
                optimizer.zero_grad()
                loss.backward()
                optimizer.step()
        Model_classifier.eval()
        with t.inference_mode():
                for (X,y) in test_dataloader:
                        X=X.to(t.float32)
                        y_preds=Model_classifier(X)
                        y_preds=y_preds.squeeze(dim=1)
                        y=y.to(t.float32)
                        loss=lossfn(y_preds,y)
                        test_loss+=loss.item()*32
                        test_acc+=(t.round(y_preds)==y).sum().item()
        train_acc_list.append(train_acc/len(train_dataloader.dataset))
        train_loss_list.append(train_loss/len(train_dataloader.dataset))
        test_acc_list.append(test_acc/len(test_dataloader.dataset))
        test_loss_list.append(test_loss/len(test_dataloader.dataset))
        print(f" \033[1;36m Epoch : {epoch} completed \033[0m")
        print(f"Training accuracy : {train_acc_list[epoch]}")
        print(f"Testing accuracy : {test_acc_list[epoch]}")
        # engine=pyttsx3.init()
        # engine.say(f"Epoch {epoch} completed ")
        
        # engine.runAndWait()
        # del engine
# Out:
#   Epoch : 0 completed
# Training accuracy : 0.058875
# Testing accuracy : 0.0015
#   Epoch : 1 completed
# Training accuracy : 0.066625
# Testing accuracy : 0.0
#   Epoch : 2 completed
# Training accuracy : 0.090875
# Testing accuracy : 0.004
#   Epoch : 3 completed
# Training accuracy : 0.08425
# Testing accuracy : 0.0
#   Epoch : 4 completed
# Training accuracy : 0.08375
# Testing accuracy : 0.0
#   Epoch : 5 completed
# Training accuracy : 0.088875
# Testing accuracy : 0.0005
#   Epoch : 6 completed
# Training accuracy : 0.107
# Testing accuracy : 0.001
#   Epoch : 7 completed
# Training accuracy : 0.071375
# Testing accuracy : 0.0
#   Epoch : 8 completed
# Training accuracy : 0.097875
# Testing accuracy : 0.001
#   Epoch : 9 completed
# Training accuracy : 0.087375
# Testing accuracy : 0.0
#   Epoch : 10 completed
# Training accuracy : 0.0795
# Testing accuracy : 0.0
#   Epoch : 11 completed
# Training accuracy : 0.081125
# Testing accuracy : 0.0
#   Epoch : 12 completed
# Training accuracy : 0.086375
# Testing accuracy : 0.0
#   Epoch : 13 completed
# Training accuracy : 0.0815
# Testing accuracy : 0.0
#   Epoch : 14 completed
# Training accuracy : 0.084
# Testing accuracy : 0.0
#   Epoch : 15 completed
# Training accuracy : 0.109125
# Testing accuracy : 0.0015
#   Epoch : 16 completed
# Training accuracy : 0.096625
# Testing accuracy : 0.001
#   Epoch : 17 completed
# Training accuracy : 0.08025
# Testing accuracy : 0.0065
#   Epoch : 18 completed
# Training accuracy : 0.089625
# Testing accuracy : 0.0
#   Epoch : 19 completed
# Training accuracy : 0.089625
# Testing accuracy : 0.0
#   Epoch : 20 completed
# Training accuracy : 0.08475
# Testing accuracy : 0.002
#   Epoch : 21 completed
# Training accuracy : 0.086125
# Testing accuracy : 0.0
#   Epoch : 22 completed
# Training accuracy : 0.093375
# Testing accuracy : 0.0
#   Epoch : 23 completed
# Training accuracy : 0.07925
# Testing accuracy : 0.0
#   Epoch : 24 completed
# Training accuracy : 0.08625
# Testing accuracy : 0.0
#   Epoch : 25 completed
# Training accuracy : 0.083875
# Testing accuracy : 0.0
#   Epoch : 26 completed
# Training accuracy : 0.080625
# Testing accuracy : 0.0015
#   Epoch : 27 completed
# Training accuracy : 0.08425
# Testing accuracy : 0.0005
#   Epoch : 28 completed
# Training accuracy : 0.06475
# Testing accuracy : 0.0
#   Epoch : 29 completed
# Training accuracy : 0.066875
# Testing accuracy : 0.0005
#   Epoch : 30 completed
# Training accuracy : 0.076
# Testing accuracy : 0.0005
#   Epoch : 31 completed
# Training accuracy : 0.08575
# Testing accuracy : 0.0
#   Epoch : 32 completed
# Training accuracy : 0.078375
# Testing accuracy : 0.0005
#   Epoch : 33 completed
# Training accuracy : 0.071625
# Testing accuracy : 0.0005
#   Epoch : 34 completed
# Training accuracy : 0.075625
# Testing accuracy : 0.0005
#   Epoch : 35 completed
# Training accuracy : 0.08425
# Testing accuracy : 0.0245
#   Epoch : 36 completed
# Training accuracy : 0.076875
# Testing accuracy : 0.0
#   Epoch : 37 completed
# Training accuracy : 0.066125
# Testing accuracy : 0.0025
#   Epoch : 38 completed
# Training accuracy : 0.07025
# Testing accuracy : 0.0005
#   Epoch : 39 completed
# Training accuracy : 0.0655
# Testing accuracy : 0.001

# %% [markdown]
# MODEL PERFORMED WORSE

# %%
#Model performed worse
